# %% [markdown]
# **HAMOYE_STAGE_B_DATA_SCIENCE**

# %%
import numpy as np
import pandas as pd

df=pd.read_csv('energydata_complete.csv')

# %%
df = df.drop(['date', 'lights'], axis = 1) 
df.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_scaled = pd.DataFrame(scaler.fit_transform(df),  columns = df.columns)

# %%
X = df_scaled.drop(columns=['Appliances'])

y = df_scaled['Appliances']

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
reg_df = df_scaled[['T2', 'T6']]

# %%
#reshaping the features
x= reg_df['T2'].values.reshape(-1,1)
y = reg_df['T6'].values.reshape(-1,1)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn import linear_model


lin_regr = linear_model.LinearRegression()
lin_regr.fit(xtrain, ytrain)
pred = lin_regr.predict(xtest)

# %% [markdown]
# QUES-12-R2_SCORE=0.62

# %%
from sklearn.metrics import r2_score

r2_score = r2_score(ytest, pred)
print((round(r2_score, 2)))
# Out:
# 0.64

# %% [markdown]
# QUES-13,14,15,16-WE CAN DIRECTLY CALCULATE ALL THE REQUIRED DATA

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
energy_pred = regr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, energy_pred)

print('MAE',(round(mae, 2)))

import numpy as np
rss = np.sum(np.square(y_test - energy_pred))
print('RSS',(round(rss, 2)))

from sklearn.metrics import  mean_squared_error

rmse = np.sqrt(mean_squared_error(y_test, energy_pred))
print('RMSE',(round(rmse, 3)))
from sklearn.metrics import r2_score

r2_score = r2_score(y_test, energy_pred) # COEFFICIENT OF DETERMINATION MEANS r_2 SCORE
print('R-squared',(round(r2_score, 2)))
# Out:
# MAE 0.05
# RSS 45.35
# RMSE 0.088
# R-squared 0.15

# %% [markdown]
# QUES-17- her ewe can see that lowest and highest weights respectivelY are RH_2, RH_1

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    
    return weights_df
linear_model_weights = get_weights_df(regr, X_train, 'Linear_Model_Weight')
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
from sklearn.linear_model import Ridge

ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(X_train, y_train)
ridge_pred = ridge_reg.predict(X_test)

# %% [markdown]
# QUES-18- here we can see there is no change in value of RMSE after ridge regression

# %%
from sklearn.metrics import  mean_squared_error

rmse = np.sqrt(mean_squared_error(y_test, ridge_pred))
print('RMSE',(round(rmse, 3)))
# Out:
# RMSE 0.088

# %%
from sklearn.linear_model import Lasso

lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)
lasso_pred = lasso_reg.predict(X_test)

# %% [markdown]
# QUES-19- here we can see there are only 4 non-zero values hence teh answee will be (4)

# %%
#Lasso regression weights
lasso_weights_df = get_weights_df(lasso_reg, X_train, 'Lasso_weight')
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %% [markdown]
# QUES-10-HERE IS THE RRQUIRED RMSE OF LASSO REGRESSION

# %%
from sklearn.metrics import  mean_squared_error

rmse = np.sqrt(mean_squared_error(y_test, lasso_pred))
print('RMSE:',(round(rmse, 3)))
# Out:
# RMSE: 0.094
